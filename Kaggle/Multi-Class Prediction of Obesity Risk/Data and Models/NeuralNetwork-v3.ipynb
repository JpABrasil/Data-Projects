# %%
import pandas as pd 
import keras
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from keras import layers
import numpy as np
# Out:
# WARNING:tensorflow:From C:\Users\joaop\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
#Importing train data and doing pre-processing
traindf = pd.read_csv("train.csv")
trainclean = traindf.loc[:,['id','Gender','Age','Height','Weight','family_history_with_overweight','FAVC','FCVC','NCP','SMOKE','CH2O','SCC','FAF','TUE','NObeyesdad']]
labelencoder1 = LabelEncoder()
labelencoder2 = LabelEncoder()
labelencoder3 = LabelEncoder()
labelencoder4 = LabelEncoder()
labelencoder5 = LabelEncoder()
labelencoder6 = LabelEncoder()
trainclean['Gender'] = labelencoder1.fit_transform(trainclean['Gender'])
trainclean['family_history_with_overweight'] = labelencoder2.fit_transform(trainclean['family_history_with_overweight'])
trainclean['FAVC'] = labelencoder3.fit_transform(trainclean['FAVC'])
trainclean['SMOKE'] = labelencoder4.fit_transform(trainclean['SMOKE'])
trainclean['SCC'] = labelencoder5.fit_transform(trainclean['SCC'])
trainclean['NObeyesdad'] = labelencoder6.fit_transform(trainclean['NObeyesdad'])
trainclean.head()
# Out:
#    id  Gender        Age    Height      Weight  \
# 0   0       1  24.443011  1.699998   81.669950
# 1   1       0  18.000000  1.560000   57.000000
# 2   2       0  18.000000  1.711460   50.165754
# 3   3       0  20.952737  1.710730  131.274851
# 4   4       1  31.641081  1.914186   93.798055
#
#    family_history_with_overweight  FAVC      FCVC       NCP  SMOKE      CH2O  \
# 0                               1     1  2.000000  2.983297      0  2.763573
# 1                               1     1  2.000000  3.000000      0  2.000000
# 2                               1     1  1.880534  1.411685      0  1.910378
# 3                               1     1  3.000000  3.000000      0  1.674061
# 4                               1     1  2.679664  1.971472      0  1.979848
#
#    SCC       FAF       TUE  NObeyesdad
# 0    0  0.000000  0.976473           6
# 1    0  1.000000  1.000000           1
# 2    0  0.866045  1.673584           0
# 3    0  1.467863  0.780199           4
# 4    0  1.967973  0.931721           6

# %%
#Separating into features and labels
Xtrain = trainclean.iloc[:,1:14]
Ytrain = trainclean.iloc[:,14]
input_dim = len(Xtrain.columns)
Ytrain.unique()
# Out:
# array([6, 1, 0, 4, 3, 5, 2])

# %%
testdf = pd.read_csv('test.csv')
cleantest =  testdf.loc[:,['id','Gender','Age','Height','Weight','family_history_with_overweight','FAVC','FCVC','NCP','SMOKE','CH2O','SCC','FAF','TUE']]
cleantest['Gender'] = labelencoder1.transform(cleantest['Gender'])
cleantest['family_history_with_overweight'] = labelencoder2.transform(cleantest['family_history_with_overweight'])
cleantest['FAVC'] = labelencoder3.transform(cleantest['FAVC'])
cleantest['SMOKE'] = labelencoder4.transform(cleantest['SMOKE'])
cleantest['SCC'] = labelencoder5.transform(cleantest['SCC'])
cleantest.head()
# Out:
#       id  Gender        Age    Height      Weight  \
# 0  20758       1  26.899886  1.848294  120.644178
# 1  20759       0  21.000000  1.600000   66.000000
# 2  20760       0  26.000000  1.643355  111.600553
# 3  20761       1  20.979254  1.553127  103.669116
# 4  20762       0  26.000000  1.627396  104.835346
#
#    family_history_with_overweight  FAVC      FCVC       NCP  SMOKE      CH2O  \
# 0                               1     1  2.938616  3.000000      0  2.825629
# 1                               1     1  2.000000  1.000000      0  3.000000
# 2                               1     1  3.000000  3.000000      0  2.621877
# 3                               1     1  2.000000  2.977909      0  2.786417
# 4                               1     1  3.000000  3.000000      0  2.653531
#
#    SCC       FAF       TUE
# 0    0  0.855400  0.000000
# 1    0  1.000000  0.000000
# 2    0  0.000000  0.250502
# 3    0  0.094851  0.000000
# 4    0  0.000000  0.741069

# %%
Xtest = cleantest.iloc[:,1:14]
Xtest.head()
# Out:
#    Gender        Age    Height      Weight  family_history_with_overweight  \
# 0       1  26.899886  1.848294  120.644178                               1
# 1       0  21.000000  1.600000   66.000000                               1
# 2       0  26.000000  1.643355  111.600553                               1
# 3       1  20.979254  1.553127  103.669116                               1
# 4       0  26.000000  1.627396  104.835346                               1
#
#    FAVC      FCVC       NCP  SMOKE      CH2O  SCC       FAF       TUE
# 0     1  2.938616  3.000000      0  2.825629    0  0.855400  0.000000
# 1     1  2.000000  1.000000      0  3.000000    0  1.000000  0.000000
# 2     1  3.000000  3.000000      0  2.621877    0  0.000000  0.250502
# 3     1  2.000000  2.977909      0  2.786417    0  0.094851  0.000000
# 4     1  3.000000  3.000000      0  2.653531    0  0.000000  0.741069

# %%
#Creating and compiling model
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(input_dim,)),
    layers.BatchNormalization(),
    layers.Dense(64,activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(64,activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(64,activation='relu'),
    layers.Dense(7, activation='softmax')
  ]  
)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

# %%
model.fit(Xtrain,Ytrain,epochs=100,batch_size=500)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 1s 13ms/step - loss: 0.1418 - accuracy: 0.9493
# Epoch 2/100
# 42/42 [==============================] - 1s 14ms/step - loss: 0.1145 - accuracy: 0.9622
# Epoch 3/100
# 42/42 [==============================] - 1s 15ms/step - loss: 0.1085 - accuracy: 0.9635
# Epoch 4/100
# 42/42 [==============================] - 1s 16ms/step - loss: 0.1044 - accuracy: 0.9638
# Epoch 5/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0994 - accuracy: 0.9661
# Epoch 6/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0958 - accuracy: 0.9694
# Epoch 7/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0952 - accuracy: 0.9685
# Epoch 8/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0929 - accuracy: 0.9688
# Epoch 9/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0913 - accuracy: 0.9698
# Epoch 10/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0878 - accuracy: 0.9709
# Epoch 11/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0869 - accuracy: 0.9720
# Epoch 12/100
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0875 - accuracy: 0.9707
# Epoch 13/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0857 - accuracy: 0.9719
# Epoch 14/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0827 - accuracy: 0.9725
# Epoch 15/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0822 - accuracy: 0.9722
# Epoch 16/100
# 42/42 [==============================] - 1s 15ms/step - loss: 0.0771 - accuracy: 0.9741
# Epoch 17/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0771 - accuracy: 0.9750
# Epoch 18/100
# 42/42 [==============================] - 1s 15ms/step - loss: 0.0793 - accuracy: 0.9739
# Epoch 19/100
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0763 - accuracy: 0.9742
# Epoch 20/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0722 - accuracy: 0.9766
# Epoch 21/100
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0736 - accuracy: 0.9754
# Epoch 22/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0718 - accuracy: 0.9766
# Epoch 23/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0715 - accuracy: 0.9756
# Epoch 24/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0688 - accuracy: 0.9778
# Epoch 25/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0692 - accuracy: 0.9778
# Epoch 26/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0695 - accuracy: 0.9763
# Epoch 27/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0681 - accuracy: 0.9780
# Epoch 28/100
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0651 - accuracy: 0.9780
# Epoch 29/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0650 - accuracy: 0.9790
# Epoch 30/100
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0675 - accuracy: 0.9771
# Epoch 31/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0618 - accuracy: 0.9795
# Epoch 32/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0627 - accuracy: 0.9793
# Epoch 33/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0676 - accuracy: 0.9769
# Epoch 34/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0608 - accuracy: 0.9803
# Epoch 35/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0623 - accuracy: 0.9790
# Epoch 36/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0611 - accuracy: 0.9788
# Epoch 37/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0620 - accuracy: 0.9790
# Epoch 38/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0623 - accuracy: 0.9790
# Epoch 39/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0630 - accuracy: 0.9782
# Epoch 40/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0674 - accuracy: 0.9750
# Epoch 41/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0620 - accuracy: 0.9790
# Epoch 42/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0574 - accuracy: 0.9818
# Epoch 43/100
# 42/42 [==============================] - 1s 16ms/step - loss: 0.0607 - accuracy: 0.9799
# Epoch 44/100
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0569 - accuracy: 0.9803
# Epoch 45/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0618 - accuracy: 0.9792
# Epoch 46/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0583 - accuracy: 0.9804
# Epoch 47/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0553 - accuracy: 0.9814
# Epoch 48/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0550 - accuracy: 0.9823
# Epoch 49/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0562 - accuracy: 0.9810
# Epoch 50/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0591 - accuracy: 0.9787
# Epoch 51/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0574 - accuracy: 0.9804
# Epoch 52/100
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0592 - accuracy: 0.9795
# Epoch 53/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0585 - accuracy: 0.9792
# Epoch 54/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0582 - accuracy: 0.9807
# Epoch 55/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0569 - accuracy: 0.9810
# Epoch 56/100
# 42/42 [==============================] - 1s 15ms/step - loss: 0.0570 - accuracy: 0.9807
# Epoch 57/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0516 - accuracy: 0.9829
# Epoch 58/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0548 - accuracy: 0.9795
# Epoch 59/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0552 - accuracy: 0.9813
# Epoch 60/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0503 - accuracy: 0.9821
# Epoch 61/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0480 - accuracy: 0.9833
# Epoch 62/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0515 - accuracy: 0.9826
# Epoch 63/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0504 - accuracy: 0.9827
# Epoch 64/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0513 - accuracy: 0.9818
# Epoch 65/100
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0510 - accuracy: 0.9825
# Epoch 66/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0510 - accuracy: 0.9819
# Epoch 67/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0513 - accuracy: 0.9827
# Epoch 68/100
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0527 - accuracy: 0.9818
# Epoch 69/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0539 - accuracy: 0.9811
# Epoch 70/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0541 - accuracy: 0.9812
# Epoch 71/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0571 - accuracy: 0.9799
# Epoch 72/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0553 - accuracy: 0.9799
# Epoch 73/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0491 - accuracy: 0.9833
# Epoch 74/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0541 - accuracy: 0.9805
# Epoch 75/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0499 - accuracy: 0.9827
# Epoch 76/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0510 - accuracy: 0.9820
# Epoch 77/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0516 - accuracy: 0.9818
# Epoch 78/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0482 - accuracy: 0.9826
# Epoch 79/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0532 - accuracy: 0.9817
# Epoch 80/100
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0496 - accuracy: 0.9831
# Epoch 81/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0532 - accuracy: 0.9821
# Epoch 82/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0508 - accuracy: 0.9823
# Epoch 83/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0495 - accuracy: 0.9821
# Epoch 84/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0485 - accuracy: 0.9831
# Epoch 85/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0460 - accuracy: 0.9843
# Epoch 86/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0481 - accuracy: 0.9835
# Epoch 87/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0478 - accuracy: 0.9836
# Epoch 88/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0467 - accuracy: 0.9844
# Epoch 89/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0481 - accuracy: 0.9837
# Epoch 90/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0449 - accuracy: 0.9840
# Epoch 91/100
# 42/42 [==============================] - 1s 15ms/step - loss: 0.0452 - accuracy: 0.9841
# Epoch 92/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0478 - accuracy: 0.9845
# Epoch 93/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0457 - accuracy: 0.9846
# Epoch 94/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0553 - accuracy: 0.9801
# Epoch 95/100
# 42/42 [==============================] - 0s 12ms/step - loss: 0.0501 - accuracy: 0.9829
# Epoch 96/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0463 - accuracy: 0.9838
# Epoch 97/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0437 - accuracy: 0.9850
# Epoch 98/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0457 - accuracy: 0.9840
# Epoch 99/100
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0462 - accuracy: 0.9840
# Epoch 100/100
# 42/42 [==============================] - 1s 12ms/step - loss: 0.0475 - accuracy: 0.9837

# %%
result =  model.predict(Xtest)
result_argmax = np.argmax(result,axis = 1)
resultdf = pd.DataFrame({"NObeyesdad":result_argmax})
resultdf['id'] = cleantest[['id']]
resultdf['NObeyesdad'] = labelencoder6.inverse_transform(resultdf['NObeyesdad'])
# Out:
# 433/433 [==============================] - 1s 2ms/step

# %%
resultdf.to_csv("NeuralNetwork-v3.csv",index = False)
