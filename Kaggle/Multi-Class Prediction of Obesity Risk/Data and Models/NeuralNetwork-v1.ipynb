# %%
import pandas as pd 
import keras
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from keras import layers
import numpy as np

# %%
#Importing train data and doing pre-processing
traindf = pd.read_csv("train.csv")
trainclean = traindf.loc[:,['id','Gender','Age','Height','Weight','family_history_with_overweight','FAVC','FCVC','NCP','SMOKE','CH2O','SCC','FAF','TUE','NObeyesdad']]
labelencoder1 = LabelEncoder()
labelencoder2 = LabelEncoder()
labelencoder3 = LabelEncoder()
labelencoder4 = LabelEncoder()
labelencoder5 = LabelEncoder()
labelencoder6 = LabelEncoder()
trainclean['Gender'] = labelencoder1.fit_transform(trainclean['Gender'])
trainclean['family_history_with_overweight'] = labelencoder2.fit_transform(trainclean['family_history_with_overweight'])
trainclean['FAVC'] = labelencoder3.fit_transform(trainclean['FAVC'])
trainclean['SMOKE'] = labelencoder4.fit_transform(trainclean['SMOKE'])
trainclean['SCC'] = labelencoder5.fit_transform(trainclean['SCC'])
trainclean['NObeyesdad'] = labelencoder6.fit_transform(trainclean['NObeyesdad'])
trainclean.head()
# Out:
#    id  Gender        Age    Height  ...  SCC       FAF       TUE  NObeyesdad
# 0   0       1  24.443011  1.699998  ...    0  0.000000  0.976473           6
# 1   1       0  18.000000  1.560000  ...    0  1.000000  1.000000           1
# 2   2       0  18.000000  1.711460  ...    0  0.866045  1.673584           0
# 3   3       0  20.952737  1.710730  ...    0  1.467863  0.780199           4
# 4   4       1  31.641081  1.914186  ...    0  1.967973  0.931721           6
#
# [5 rows x 15 columns]

# %%
#Separating into features and labels
Xtrain = trainclean.iloc[:,1:14]
Ytrain = trainclean.iloc[:,14]
input_dim = len(Xtrain.columns)
Ytrain.unique()
# Out:
# array([6, 1, 0, 4, 3, 5, 2])

# %%
#Creating and compiling model
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(input_dim,)),
    layers.Dense(64,activation='relu'),
    layers.Dense(64,activation='relu'),
    layers.Dense(64,activation='relu'),
    layers.Dense(7, activation='softmax')
  ]  
)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 7
#       1 #Creating and compiling model
#       2 model = keras.Sequential([
#       3     layers.Dense(64, activation='relu', input_shape=(input_dim,)),
#       4     layers.Dense(64,activation='relu'),
#       5     layers.Dense(64,activation='relu'),
#       6     layers.Dense(64,activation='relu'),
# ----> 7     layers.Dense(7, activation='argmax')
#       8   ]
#       9 )
#      10 model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#      11 model.summary()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\dtensor\utils.py:96, in allow_initializer_layout.<locals>._wrap_function(layer_instance, *args, **kwargs)
#      93         if layout:
#      94             layout_args[variable_name + "_layout"] = layout
# ---> 96 init_method(layer_instance, *args, **kwargs)
#      98 # Inject the layout parameter after the invocation of __init__()
#      99 for layout_param_name, layout in layout_args.items():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:125, in Dense.__init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     120 if self.units < 0:
#     121     raise ValueError(
#     122         "Received an invalid value for `units`, expected "
#     123         f"a positive integer. Received: units={units}"
#     124     )
# --> 125 self.activation = activations.get(activation)
#     126 self.use_bias = use_bias
#     127 self.kernel_initializer = initializers.get(kernel_initializer)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\activations.py:691, in get(identifier)
#     685 if isinstance(identifier, (str, dict)):
#     686     use_legacy_format = (
#     687         "module" not in identifier
#     688         if isinstance(identifier, dict)
#     689         else False
#     690     )
# --> 691     return deserialize(identifier, use_legacy_format=use_legacy_format)
#     692 elif callable(identifier):
#     693     return identifier
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\activations.py:646, in deserialize(name, custom_objects, use_legacy_format)
#     638 returned_fn = serialization_lib.deserialize_keras_object(
#     639     name,
#     640     module_objects=activation_functions,
#     641     custom_objects=custom_objects,
#     642     printable_module_name="activation function",
#     643 )
#     645 if isinstance(returned_fn, str):
# --> 646     raise ValueError(
#     647         f"Unknown activation function '{name}' cannot be deserialized."
#     648     )
#     650 return returned_fn
#
# ValueError: Unknown activation function 'argmax' cannot be deserialized.

# %%
#Training model
model.fit(Xtrain,Ytrain, epochs= 30, batch_size=50)
# Out:
# Epoch 1/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.4177 - accuracy: 0.8432
# Epoch 2/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.4098 - accuracy: 0.8459
# Epoch 3/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.4127 - accuracy: 0.8447
# Epoch 4/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.4059 - accuracy: 0.8465
# Epoch 5/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.4033 - accuracy: 0.8486
# Epoch 6/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.4059 - accuracy: 0.8493
# Epoch 7/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.4018 - accuracy: 0.8489
# Epoch 8/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.4063 - accuracy: 0.8459
# Epoch 9/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.4000 - accuracy: 0.8491
# Epoch 10/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3995 - accuracy: 0.8513
# Epoch 11/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3999 - accuracy: 0.8492
# Epoch 12/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3930 - accuracy: 0.8528
# Epoch 13/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3944 - accuracy: 0.8511
# Epoch 14/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3913 - accuracy: 0.8535
# Epoch 15/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3936 - accuracy: 0.8521
# Epoch 16/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3943 - accuracy: 0.8523
# Epoch 17/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3962 - accuracy: 0.8518
# Epoch 18/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3871 - accuracy: 0.8551
# Epoch 19/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3890 - accuracy: 0.8539
# Epoch 20/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3859 - accuracy: 0.8553
# Epoch 21/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3894 - accuracy: 0.8528
# Epoch 22/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3881 - accuracy: 0.8569
# Epoch 23/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3825 - accuracy: 0.8553
# Epoch 24/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3872 - accuracy: 0.8570
# Epoch 25/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3847 - accuracy: 0.8551
# Epoch 26/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3874 - accuracy: 0.8568
# Epoch 27/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3794 - accuracy: 0.8590
# Epoch 28/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3853 - accuracy: 0.8543
# Epoch 29/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3750 - accuracy: 0.8600
# Epoch 30/30
# 416/416 [==============================] - 1s 2ms/step - loss: 0.3793 - accuracy: 0.8574

# %%
testdf = pd.read_csv('test.csv')
cleantest =  testdf.loc[:,['id','Gender','Age','Height','Weight','family_history_with_overweight','FAVC','FCVC','NCP','SMOKE','CH2O','SCC','FAF','TUE']]
cleantest['Gender'] = labelencoder1.transform(cleantest['Gender'])
cleantest['family_history_with_overweight'] = labelencoder2.transform(cleantest['family_history_with_overweight'])
cleantest['FAVC'] = labelencoder3.transform(cleantest['FAVC'])
cleantest['SMOKE'] = labelencoder4.transform(cleantest['SMOKE'])
cleantest['SCC'] = labelencoder5.transform(cleantest['SCC'])
cleantest.head()
# Out:
#       id  Gender        Age    Height  ...      CH2O  SCC       FAF       TUE
# 0  20758       1  26.899886  1.848294  ...  2.825629    0  0.855400  0.000000
# 1  20759       0  21.000000  1.600000  ...  3.000000    0  1.000000  0.000000
# 2  20760       0  26.000000  1.643355  ...  2.621877    0  0.000000  0.250502
# 3  20761       1  20.979254  1.553127  ...  2.786417    0  0.094851  0.000000
# 4  20762       0  26.000000  1.627396  ...  2.653531    0  0.000000  0.741069
#
# [5 rows x 14 columns]

# %%
Xtest = cleantest.iloc[:,1:14]
Xtest.head()
# Out:
#    Gender        Age    Height      Weight  ...      CH2O  SCC       FAF       TUE
# 0       1  26.899886  1.848294  120.644178  ...  2.825629    0  0.855400  0.000000
# 1       0  21.000000  1.600000   66.000000  ...  3.000000    0  1.000000  0.000000
# 2       0  26.000000  1.643355  111.600553  ...  2.621877    0  0.000000  0.250502
# 3       1  20.979254  1.553127  103.669116  ...  2.786417    0  0.094851  0.000000
# 4       0  26.000000  1.627396  104.835346  ...  2.653531    0  0.000000  0.741069
#
# [5 rows x 13 columns]

# %%
result =  model.predict(Xtest)
# Out:
# 433/433 [==============================] - 1s 1ms/step

# %%
result_argmax = np.argmax(result,axis = 1)

# %%
resultdf = pd.DataFrame({"NObeyesdad":result_argmax})

# %%
resultdf.head()
# Out:
#    NObeyesdad
# 0           3
# 1           5
# 2           4
# 3           3
# 4           4

# %%
resultdf['id'] = cleantest[['id']]
resultdf['NObeyesdad'] = labelencoder6.inverse_transform(resultdf['NObeyesdad'])

# %%
resultdf.head()
# Out:
#            NObeyesdad     id
# 0     Obesity_Type_II  20758
# 1  Overweight_Level_I  20759
# 2    Obesity_Type_III  20760
# 3     Obesity_Type_II  20761
# 4    Obesity_Type_III  20762

# %%
resultdf.to_csv("NeuralNetwork-v1.csv",index = False)
